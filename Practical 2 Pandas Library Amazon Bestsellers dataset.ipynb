# %% [markdown]
# # Practical 2

# %% [markdown]
# # Demonstrate loading data from CSV file, reading and manipulation of dataset using Pandas library on Amazon Bestsellers Dataset 2020 and Ramen Ratings dataset 2015-2019.

# %%
#Date : 06/10/2022

# %%
import numpy as np
import math
import pandas as pd
print(pd.__version__) #printing version of pandas library
# Out:
# 1.3.4

# %%
#Creating an empty series
series1 = pd.Series()
print(series1)
# Out:
# Series([], dtype: float64)
# C:\Users\panka\AppData\Local\Temp/ipykernel_10540/335453546.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   series1 = pd.Series()

# %%
list1 = ['h','e','l','l','o',2022,1.0]
series = pd.Series(list1) #creating series from a list
print(series)
# Out:
# 0       h
# 1       e
# 2       l
# 3       l
# 4       o
# 5    2022
# 6     1.0
# dtype: object

# %%
#creating an empty dataframe
#Creating a dataframe
df = pd.DataFrame() #No parameter
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list1 = ['Hello', 'all','users', 23,45.8]
df = pd.DataFrame(list1) #creating dataframe using list
print(df)
# Out:
#        0
# 0  Hello
# 1    all
# 2  users
# 3     23
# 4   45.8

# %%
#use complete path to open files.
#instead of \ use / slash in paths because the notebook is running on localhost web.

#reading csv file
df1 = pd.read_csv('D:/ML Dataset/bestsellers with categories.csv') #Absolute complete path location
df1 #loading the data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#reading csv file
df1 = pd.read_excel('D:/ML Dataset/bestsellers with categories.xlsx') #Absolute complete path location
df1 #loading the data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df1.head() #read top 5 rows only
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df1.head(20) #read first 20 rows only
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
df1.head(-10) #read all rows except last 10 rows
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 535                          Where the Wild Things Are
# 536  Whose Boat Is This Boat?: Comments That Don't ...
# 537  Wild: From Lost to Found on the Pacific Crest ...
# 538  Winter of the World: Book Two of the Century T...
# 539  Women Food and God: An Unexpected Path to Almo...
#
#                                 Author  User Rating  Reviews  Price  Year  \
# 0                             JJ Smith          4.7    17350      8  2016
# 1                         Stephen King          4.6     2052     22  2011
# 2                   Jordan B. Peterson          4.7    18979     15  2018
# ...

# %%
df1.tail() #print last 5 rows
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
# .columns is a property not a function
df1.columns #for printing column names of dataframe
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
#df1.shape
df1.shape #gives no. of rows and columns.
# Out:
# (550, 7)

# %%
#the append() method will return a copy of dataframe by adding new dataframe to original dataframe
#here df1 is added to df1 doubling it up to 1100 rows
#appending occurs only by matching the labels of the columns
#indexes of second dataset don't changes they remain same

temp_df1 = df1.append(df1)
temp_df1.shape
temp_df1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#drop_duplicates() method will return a copy of your DataFrame with duplicates removed from it.

temp_df2 = temp_df1.drop_duplicates()

temp_df2.shape
temp_df2
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#an important argument for drop_duplicates() is keep, which has three possible options:

#1. first:(default) Drop duplicates except for the first occurrence.
#2. last: drop duplicates except for the last occurrence.
#3. false: drop all duplicates.

#Aslso, using inplace = True will modify the DataFrame object in place.

# %%
temp_df1.drop_duplicates(inplace=True, keep='first')
temp_df1.shape
# Out:
# (550, 7)

# %%
temp_df1.drop_duplicates(inplace=True, keep='last')
temp_df1.shape
# Out:
# (550, 7)

# %% [markdown]
# temp_df1.drop_duplicates(inplace = True, keep ='False')
# temp_df1.shape

# %%
temp_df1.drop_duplicates(inplace=True, keep=False)
temp_df1.shape
# Out:
# (550, 7)

# %% [markdown]
# # Lab 4

# %%
# Date : 07/10/2022

# %%
# We can get info about your data using info() method.
# The info() method provides the essential information about our dataset:
# 1. The number of rows and columns, 
# 2. The number of non-null values, 
# 3. The type of data is in each column, 
# 4. The amount of memory our DataFrame is using.

# %%
df1 = pd.read_csv("D:/ML Dataset/bestsellers with categories.csv") #Absolute complete path location
df1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# To print the column names
df1.isnull
# Out:
# <bound method DataFrame.isnull of                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df1.shape #shows no. of rows and columns
# Out:
# (550, 7)

# %%
# The .rename() method to rename some or all columns of a dataframe via a dict.
df1.rename(columns={
    'Author':'Writer',
    'Price':'Amount'}, inplace = True)
df1.columns
# Out:
# Index(['Name', 'Writer', 'User Rating', 'Reviews', 'Amount', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# # Matplotlib Library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Date : 13/10/2022
#Dataset : winemag-data-130k-v2.csv

# %%
df = pd.read_csv("D:/ML Dataset/winemag-data-130k-v2.csv")
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# # Questions

# %% [markdown]
# Q1. Find the datatype of Price Column
# Q2. Find the datatype of all the column in the single command
# Q3. Change the type of point columns to float and view that.
# Q4. Check is the dataframe consist of any Null Values  (NaN values)
# Q5. Replace each column's Null values with either a constant or mean value.
# Q6. Check if deleting the column or row gives a better approach of removing Nulls

# %%
# Q1. Find the datatype of Price Column
df['price'].dtype #finding a datatype for a particular column
# Out:
# dtype('float64')

# %%
#Q.2 Find the datatype of all the column in the single command
df.dtypes #for printing data types of all the columns
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
#Q.3 Change the type of point columns to float and view that.
df['points']=df['points'].astype('float') # for changing the datatype of a particular column
df.head() #finding data types of all the columns
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points      price           province  \
# 0                        Vulkà Bianco    87.0  35.363389  Sicily & Sardinia
# 1                            Avidagos    87.0  15.000000              Douro
# 2                                  NA    87.0  14.000000             Oregon
# 3                Reserve Late Harvest    87.0  13.000000           Michigan
# 4  Vintner's Reserve Wild Child Block    87.0  65.000000             Oregon
#
# ...

# %%
#Q4. Check is the dataframe consist of any Null Values  (NaN values) 
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
df.isnull().sum().sum() #total null values in the dataset.
# Out:
# 204752

# %%
#Q5. Replace each column's Null values with either a constant or mean value.
df['country'].fillna("No Country", inplace=True) #replacing null values in country with "No country"
df['designation'].fillna("NA", inplace=True) #replacing null values in designation with "NA"

#replacing null values of price with the mean of price column
df['price'].fillna(df['price'].mean(), inplace= True)
df['province'].fillna("NA", inplace=True)
df['region_1'].fillna("NA", inplace=True)
df['region_2'].fillna("NA", inplace=True)
df['taster_name'].fillna("Unknown", inplace=True)
df['taster_twitter_handle'].fillna("Unknown", inplace=True)
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.isnull().sum() #counting null values for each column
# Out:
# Unnamed: 0               0
# country                  0
# description              0
# designation              0
# points                   0
# price                    0
# province                 0
# region_1                 0
# region_2                 0
# taster_name              0
# taster_twitter_handle    0
# title                    0
# variety                  1
# winery                   0
# dtype: int64

# %%
#Q6. Check if deleting the column or row gives a better approach of removing Nulls'''
