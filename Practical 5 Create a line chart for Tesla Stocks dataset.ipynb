# %% [markdown]
# # Practical 5

# %% [markdown]
# # Demonstrate a Line chart using Tesla Stocks High Price dataset for 2016-2018.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Dataset : Tesla Stock Price Dataset

# %%
stock_data = pd.read_csv("D:/ML dataset/tesla-stock-price.csv")
stock_data
# Out:
#            date   close    volume    open      high       low
# 0    10/15/2018  259.59   6189026  259.06  263.2800  254.5367
# 1    10/12/2018  258.78   7189257  261.00  261.9900  252.0100
# 2    10/11/2018  252.23   8128184  257.53  262.2500  249.0300
# 3    10/10/2018  256.88  12781560  264.61  265.5100  247.7700
# 4     10/9/2018  262.80  12037780  255.25  266.7700  253.3000
# ..          ...     ...       ...     ...       ...       ...
# 751  10/21/2015  210.09   4177956  211.99  214.8100  208.8000
# 752  10/20/2015  213.03  14877020  227.72  228.6000  202.0000
# 753  10/19/2015  228.10   2506836  226.50  231.1500  224.9400
# 754  10/16/2015  227.01   4327574  223.04  230.4805  222.8700
# 755  10/15/2015  221.31   2835920  216.43  221.7300  213.7000
#
# [756 rows x 6 columns]

# %%
stock_data.head()
# Out:
#          date   close    volume    open    high       low
# 0  10/15/2018  259.59   6189026  259.06  263.28  254.5367
# 1  10/12/2018  258.78   7189257  261.00  261.99  252.0100
# 2  10/11/2018  252.23   8128184  257.53  262.25  249.0300
# 3  10/10/2018  256.88  12781560  264.61  265.51  247.7700
# 4   10/9/2018  262.80  12037780  255.25  266.77  253.3000

# %%
# for ignoring all random warnings in the jupyter file
import warnings
warnings.filterwarnings('ignore')

# %%
stock_data['date'] = pd.to_datetime(stock_data['date']) #converts date into datetime format with hyphens instead of slashes
stock_data.head()
# Out:
#         date   close    volume    open    high       low
# 0 2018-10-15  259.59   6189026  259.06  263.28  254.5367
# 1 2018-10-12  258.78   7189257  261.00  261.99  252.0100
# 2 2018-10-11  252.23   8128184  257.53  262.25  249.0300
# 3 2018-10-10  256.88  12781560  264.61  265.51  247.7700
# 4 2018-10-09  262.80  12037780  255.25  266.77  253.3000

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0,0,1,1])
ax1.set_title('Tesla Stocks High Stock Prices')
ax1.plot(stock_data['date'],stock_data['high'],color='red')
ax1.plot(stock_data['date'],stock_data['low'],color='black')
plt.xticks(rotation=90)
ax1.grid()
plt.show()
